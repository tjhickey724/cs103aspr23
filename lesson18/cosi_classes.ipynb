# %% [markdown]
# # Analysis of Brandeis Computer Science classes using Pandas
# Here we show how to use pandas to analyze the Brandeis course data stored in data/courses
#
# Some questions we can try to answer
# * which faculty have taught the most students over the Fall2004-Summer2021 interval
# * which departments offer the most courses
# * which departments have had the most students
# * how have the enrollents by departments changed
# * etc, as in PA01
#
# We'll show how to use pivot tables and aggregation to answer some of these.
#
# This notebook shows how to use aggregation with groupby, pivot tables, and how to create new columns by applying some function to other columns.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# First we read in the data from Fall 2004 to Summer 2021 with minimal info about each course

# %%
df = pd.read_csv('data/courses.csv')
df
# Out:
#        subj  num suf format         term  code                       inst  \
# 0      NEJS  188   A    LEC    Fall 2004  1043              Levy, Avigdor
# 1      CHEM  121   A    LEC    Fall 2004  1043              Foxman, Bruce
# 2      CHEM  130   A    LEC    Fall 2004  1043                Yu, Jinquan
# 3      COMP    1   A    LEC    Fall 2004  1043             Ruesch, Gordon
# 4       MUS  118   A    STD    Fall 2004  1043                  Ray, Mary
# ...     ...  ...  ..    ...          ...   ...                        ...
# 35201  BIOL   26   A    LEC  Summer 2021  1212  Kosinski-Collins, Melissa
# 35202  ECON   28   B    LEC  Summer 2021  1212         AlMehdar, Mohammed
# 35203  PHIL    1   A    LEC  Summer 2021  1212                Lupu, Peter
# 35204  AAAS  160   B    LEC  Summer 2021  1212         Plumb, Betsy Loren
# 35205   IGS  130   A    LEC  Summer 2021  1212            Campion, Selene
#
#                                                    title sec  enr
# 0                               RISE/DECLINE:OTTOMAN EMP   1   32
# 1                                INORGANIC CHEM I, LECS.   1   18
# 2                               ADV ORG. CHEM: STRUCTURE   1   14
# 3                                            COMPOSITION   3   11
# 4                                       SENIOR RECITAL I   1    3
# ...                                                  ...  ..  ...
# 35201                                      Plant Biology   1    9
# 35202                                 The Global Economy   1    4
# 35203                         Introduction to Philosophy   1    3
# 35204  If We Must Die: War and Military Service in Af...   1    3
# 35205                                   Global Migration   1    1
#
# [35206 rows x 10 columns]

# %%
cs = df[df['subj']=='COSI'].copy()
cs
# Out:
#        subj  num suf format         term  code                  inst  \
# 63     COSI  171   A    LEC    Fall 2004  1043          Cohn, Martin
# 107    COSI  112   A    LEC    Fall 2004  1043    Pustejovsky, James
# 144    COSI    2   A    LEC    Fall 2004  1043       Hickey, Timothy
# 403    COSI   31   A    LEC    Fall 2004  1043      Cherniack, Mitch
# 492    COSI  215   A    SEM    Fall 2004  1043     Alterman, Richard
# ...     ...  ...  ..    ...          ...   ...                   ...
# 34879  COSI   10   A    LEC    Fall 2020  1203  Tsekourakis, Iraklis
# 34969  COSI   10   A    LEC    Fall 2020  1203     Hickey, Timothy J
# 35149  COSI   12   B    LEC  Summer 2021  1212     Golitsyn, Michael
# 35171  COSI  152   A    LEC  Summer 2021  1212     Hickey, Timothy J
# 35172  COSI  153   A    LEC  Summer 2021  1212     Hickey, Timothy J
#
#                                            title  sec  enr
# 63                                    CRYPTOLOGY    1   23
# 107                     THRY/MODELS:INTEL.BEHAVR    1   23
# 144                           INTRO TO COMPUTERS    1   86
# 403                     COMPUTER STRUCTURES/ORG.    1   34
# 492                     ADV.TOPIC:HMAN-CENT COMP    1   10
# ...                                          ...  ...  ...
# 34879  Introduction to Problem Solving in Python    2   67
# 34969  Introduction to Problem Solving in Python  3DL   25
# 35149    Advanced Programming Techniques in Java    1   11
# 35171                Web Application Development    1   18
# 35172             Mobile Application Development    1    9
#
# [589 rows x 10 columns]

# %%
cs['inst'] = cs['inst'].apply(lambda x: "Hickey, Timothy" if x=="Hickey, Timothy J" else x)
cs['inst'] = cs['inst'].apply(lambda x: 'DiLillo, Antonella' if x=="Di Lillo, Antonella" else x)
cs['inst'] = cs['inst'].apply(lambda x: 'Salas, R. Pito' if x=="Salas, Ralph" else x)
cs['inst'] = cs['inst'].apply(lambda x: 'Anick, Peter' if x=="Anick, Peter G." else x)
cs['inst'] = cs['inst'].apply(lambda x: 'Storer, James' if x=="Storer, James A" else x)
cs['inst'] = cs['inst'].apply(lambda x: 'Wellner, Benjamin' if x=="Wellner, Benjamin R." else x)

# %% [markdown]
# # Finding teachers with the most students
# The easiest way to do this is with a groupby it shows the three stages of groupby
# 1. grouping of rows together based on the value in a column ('inst')
# 1. projection of those rows into a set of values (what value are we interested in) (enr)
# 1. aggregation of those values into a single value with some operator from arrays to numbers (sum)

# %%
#fac = df.groupby(['inst','subject'])['enr'].agg(sum)
#fac
fac = cs.groupby(['inst','subj'])
fac = fac['enr'].agg([sum, np.mean,np.median, np.max,len])
fac = fac.sort_values(ascending=False,by='len')
fac.head(100)
# Out:
#                               sum       mean  median  amax  len
# inst                   subj
# Hickey, Timothy        COSI  3795  48.653846    19.0   169   78
# DiLillo, Antonella     COSI  4697  66.154930    65.0   149   71
# Salas, R. Pito         COSI  1140  27.804878    23.0    92   41
# Storer, James          COSI  1408  41.411765    30.0   140   34
# Mairson, Harry         COSI  1156  36.125000    23.5   108   32
# Pustejovsky, James     COSI   773  24.935484    22.0    81   31
# Alterman, Richard      COSI  1100  35.483871    25.0   116   31
# Meteer, Marie          COSI   435  15.000000    16.0    32   29
# Hong, Pengyu           COSI   854  29.448276    24.0    77   29
# Cherniack, Mitch       COSI  1547  55.250000    36.5   154   28
# Shrira, Liuba          COSI   938  36.076923    17.0   132   26
# Papaemmanouil, Olga    COSI   962  48.100000    36.5   134   20
# Pollack, Jordan        COSI   648  32.400000    19.0   108   20
# Xue, Nianwen           COSI   302  15.894737    15.0    46   19
# Colon Osorio, Fernando COSI   159   9.937500     8.0    24   16
# Wellner, Benjamin      COSI   197  17.909091    15.0    33   11
# Anick, Peter           COSI   163  20.375000    24.0    27    8
# Liu, Hongfu            COSI   180  30.000000    26.5    64    6
# Chaturvedi, Praveen    COSI   312  52.000000    56.0    67    6
# Goldberg, Lotus        COSI    37   7.400000     9.0    11    5
# Tsekourakis, Iraklis   COSI   322  64.400000    67.0    94    5
# Lignos, Constantine    COSI   146  36.500000    25.0    84    4
# Gessel, Ira            COSI    67  16.750000    16.0    27    4
# Plaster, Keith         COSI    68  17.000000    14.5    31    4
# Wittenberg, David      COSI    70  23.333333    16.0    39    3
# Golitsyn, Michael      COSI    45  15.000000    13.0    21    3
# Cohen, Jacques         COSI    44  14.666667    15.0    19    3
# Tresner-Kirsch, David  COSI    25  12.500000    12.5    19    2
# Abi-Antoun, Marwan     COSI    40  20.000000    20.0    22    2
# Cohn, Martin           COSI    46  23.000000    23.0    23    2
# Zhang, Chuxu           COSI    26  13.000000    13.0    17    2
# Wittenberg, William    COSI    18   9.000000     9.0    10    2
# Verhagen, Marcus E.    COSI     5   5.000000     5.0     5    1
# Marcus, Ryan           COSI    81  81.000000    81.0    81    1
# Shaull, Ross           COSI     7   7.000000     7.0     7    1
# Plotnick, Alexander    COSI    35  35.000000    35.0    35    1
# Naamad, Amnon          COSI    24  24.000000    24.0    24    1
# Moszkowicz, Jessica    COSI    18  18.000000    18.0    18    1
# Loper, Edward          COSI     9   9.000000     9.0     9    1
# Larusson, Johann       COSI    35  35.000000    35.0    35    1
# Landsman, Seth         COSI    29  29.000000    29.0    29    1
# Garber, Solomon        COSI    40  40.000000    40.0    40    1
# Anick, Peter G         COSI    32  32.000000    32.0    32    1
# Zimmerman, Grace       COSI    18  18.000000    18.0    18    1

# %% [markdown]
# ## Sorting the Series
# We can sort the values if we want (and here I am then reversing them by iterating with a step of -1 through the array) and we can use .head(N) and .tail(N) to look at either end of the sorted series.

# %%
fac = fac.sort_values(ascending=False,by='len')
fac.head(20)
# Out:
#                               sum       mean  median  amax  len
# inst                   subj
# Hickey, Timothy        COSI  3795  48.653846    19.0   169   78
# DiLillo, Antonella     COSI  4697  66.154930    65.0   149   71
# Salas, R. Pito         COSI  1140  27.804878    23.0    92   41
# Storer, James          COSI  1408  41.411765    30.0   140   34
# Mairson, Harry         COSI  1156  36.125000    23.5   108   32
# Alterman, Richard      COSI  1100  35.483871    25.0   116   31
# Pustejovsky, James     COSI   773  24.935484    22.0    81   31
# Hong, Pengyu           COSI   854  29.448276    24.0    77   29
# Meteer, Marie          COSI   435  15.000000    16.0    32   29
# Cherniack, Mitch       COSI  1547  55.250000    36.5   154   28
# Shrira, Liuba          COSI   938  36.076923    17.0   132   26
# Papaemmanouil, Olga    COSI   962  48.100000    36.5   134   20
# Pollack, Jordan        COSI   648  32.400000    19.0   108   20
# Xue, Nianwen           COSI   302  15.894737    15.0    46   19
# Colon Osorio, Fernando COSI   159   9.937500     8.0    24   16
# Wellner, Benjamin      COSI   197  17.909091    15.0    33   11
# Anick, Peter           COSI   163  20.375000    24.0    27    8
# Chaturvedi, Praveen    COSI   312  52.000000    56.0    67    6
# Liu, Hongfu            COSI   180  30.000000    26.5    64    6
# Goldberg, Lotus        COSI    37   7.400000     9.0    11    5

# %%
fac.head(50)
# Out:
#                               sum       mean  median  amax  len
# inst                   subj
# Hickey, Timothy        COSI  3795  48.653846    19.0   169   78
# DiLillo, Antonella     COSI  4697  66.154930    65.0   149   71
# Salas, R. Pito         COSI  1140  27.804878    23.0    92   41
# Storer, James          COSI  1408  41.411765    30.0   140   34
# Mairson, Harry         COSI  1156  36.125000    23.5   108   32
# Alterman, Richard      COSI  1100  35.483871    25.0   116   31
# Pustejovsky, James     COSI   773  24.935484    22.0    81   31
# Hong, Pengyu           COSI   854  29.448276    24.0    77   29
# Meteer, Marie          COSI   435  15.000000    16.0    32   29
# Cherniack, Mitch       COSI  1547  55.250000    36.5   154   28
# Shrira, Liuba          COSI   938  36.076923    17.0   132   26
# Papaemmanouil, Olga    COSI   962  48.100000    36.5   134   20
# Pollack, Jordan        COSI   648  32.400000    19.0   108   20
# Xue, Nianwen           COSI   302  15.894737    15.0    46   19
# Colon Osorio, Fernando COSI   159   9.937500     8.0    24   16
# Wellner, Benjamin      COSI   197  17.909091    15.0    33   11
# Anick, Peter           COSI   163  20.375000    24.0    27    8
# Chaturvedi, Praveen    COSI   312  52.000000    56.0    67    6
# Liu, Hongfu            COSI   180  30.000000    26.5    64    6
# Goldberg, Lotus        COSI    37   7.400000     9.0    11    5
# Tsekourakis, Iraklis   COSI   322  64.400000    67.0    94    5
# Lignos, Constantine    COSI   146  36.500000    25.0    84    4
# Plaster, Keith         COSI    68  17.000000    14.5    31    4
# Gessel, Ira            COSI    67  16.750000    16.0    27    4
# Golitsyn, Michael      COSI    45  15.000000    13.0    21    3
# Cohen, Jacques         COSI    44  14.666667    15.0    19    3
# Wittenberg, David      COSI    70  23.333333    16.0    39    3
# Cohn, Martin           COSI    46  23.000000    23.0    23    2
# Abi-Antoun, Marwan     COSI    40  20.000000    20.0    22    2
# Wittenberg, William    COSI    18   9.000000     9.0    10    2
# Tresner-Kirsch, David  COSI    25  12.500000    12.5    19    2
# Zhang, Chuxu           COSI    26  13.000000    13.0    17    2
# Larusson, Johann       COSI    35  35.000000    35.0    35    1
# Anick, Peter G         COSI    32  32.000000    32.0    32    1
# Landsman, Seth         COSI    29  29.000000    29.0    29    1
# Plotnick, Alexander    COSI    35  35.000000    35.0    35    1
# Marcus, Ryan           COSI    81  81.000000    81.0    81    1
# Naamad, Amnon          COSI    24  24.000000    24.0    24    1
# Moszkowicz, Jessica    COSI    18  18.000000    18.0    18    1
# Garber, Solomon        COSI    40  40.000000    40.0    40    1
# Zimmerman, Grace       COSI    18  18.000000    18.0    18    1
# Loper, Edward          COSI     9   9.000000     9.0     9    1
# Shaull, Ross           COSI     7   7.000000     7.0     7    1
# Verhagen, Marcus E.    COSI     5   5.000000     5.0     5    1

# %%
df
# Out:
#        subj  num suf format         term  code                       inst  \
# 0      NEJS  188   A    LEC    Fall 2004  1043              Levy, Avigdor
# 1      CHEM  121   A    LEC    Fall 2004  1043              Foxman, Bruce
# 2      CHEM  130   A    LEC    Fall 2004  1043                Yu, Jinquan
# 3      COMP    1   A    LEC    Fall 2004  1043             Ruesch, Gordon
# 4       MUS  118   A    STD    Fall 2004  1043                  Ray, Mary
# ...     ...  ...  ..    ...          ...   ...                        ...
# 35201  BIOL   26   A    LEC  Summer 2021  1212  Kosinski-Collins, Melissa
# 35202  ECON   28   B    LEC  Summer 2021  1212         AlMehdar, Mohammed
# 35203  PHIL    1   A    LEC  Summer 2021  1212                Lupu, Peter
# 35204  AAAS  160   B    LEC  Summer 2021  1212         Plumb, Betsy Loren
# 35205   IGS  130   A    LEC  Summer 2021  1212            Campion, Selene
#
#                                                    title sec  enr
# 0                               RISE/DECLINE:OTTOMAN EMP   1   32
# 1                                INORGANIC CHEM I, LECS.   1   18
# 2                               ADV ORG. CHEM: STRUCTURE   1   14
# 3                                            COMPOSITION   3   11
# 4                                       SENIOR RECITAL I   1    3
# ...                                                  ...  ..  ...
# 35201                                      Plant Biology   1    9
# 35202                                 The Global Economy   1    4
# 35203                         Introduction to Philosophy   1    3
# 35204  If We Must Die: War and Military Service in Af...   1    3
# 35205                                   Global Migration   1    1
#
# [35206 rows x 10 columns]

# %% [markdown]
# # Restricting to a time interval
# Let's do the same but just look for the past 4 years, i.e. from Fall2017 to Summer 2021 which are the codes 1173 to 1212.

# %%
df2 = cs[cs['code']>=1193]
df2
#islater = df['code']>= 1173
#df[islater]
# Out:
#        subj  num suf format         term  code                  inst  \
# 2070   COSI  119   A    LAB    Fall 2019  1193        Salas, R. Pito
# 2071   COSI  119   A    LAB    Fall 2019  1193        Salas, R. Pito
# 2117   COSI   45   A    LAB  Spring 2020  1201   Wittenberg, William
# 14616  COSI  190   A    LEC    Fall 2019  1193        Mairson, Harry
# 14617  COSI  177   A    LEC    Fall 2019  1193    Abi-Antoun, Marwan
# ...     ...  ...  ..    ...          ...   ...                   ...
# 34879  COSI   10   A    LEC    Fall 2020  1203  Tsekourakis, Iraklis
# 34969  COSI   10   A    LEC    Fall 2020  1203       Hickey, Timothy
# 35149  COSI   12   B    LEC  Summer 2021  1212     Golitsyn, Michael
# 35171  COSI  152   A    LEC  Summer 2021  1212       Hickey, Timothy
# 35172  COSI  153   A    LEC  Summer 2021  1212       Hickey, Timothy
#
#                                            title  sec  enr
# 2070                         AUTONOMOUS ROBOTICS    1    6
# 2071                         AUTONOMOUS ROBOTICS    2    8
# 2117                EFF COMM COMPUTER SCIENTISTS    1   10
# 14616                    PROGRAMMING LANG.THEORY    1   11
# 14617                 SCIENTIFIC DATA PROCESSING    1   22
# ...                                          ...  ...  ...
# 34879  Introduction to Problem Solving in Python    2   67
# 34969  Introduction to Problem Solving in Python  3DL   25
# 35149    Advanced Programming Techniques in Java    1   11
# 35171                Web Application Development    1   18
# 35172             Mobile Application Development    1    9
#
# [91 rows x 10 columns]

# %% [markdown]
# ## aggregate by summing the enrollments for each subject

# %%
insts = df2.groupby(['inst'])['enr'].agg(sum)
insts = insts.sort_values(ascending=False)
insts.head(20)
# Out:
# inst
# DiLillo, Antonella      943
# Hickey, Timothy         733
# Cherniack, Mitch        347
# Tsekourakis, Iraklis    322
# Papaemmanouil, Olga     235
# Salas, R. Pito          220
# Hong, Pengyu            199
# Storer, James           162
# Mairson, Harry          153
# Lignos, Constantine     146
# Pustejovsky, James      136
# Pollack, Jordan         122
# Liu, Hongfu             119
# Xue, Nianwen            116
# Alterman, Richard       114
# Wellner, Benjamin        48
# Abi-Antoun, Marwan       40
# Golitsyn, Michael        32
# Anick, Peter G           32
# Plaster, Keith           31
# Name: enr, dtype: int64

# %% [markdown]
# # Time series
# Now lets try to get time series data and plot the enrollments in a department by year.
# Let's first add a new column giving the academic year, so Fall2004 and Spring 2005 and Summer2005 would all be 2004

# %%
def code2year(code):
    ''' returns the academic year corresponding to a code'''
    code=str(code)
    year = int("20"+code[1:-1])
    if code[-1]!='3':
        year = year -1
    return year
print(code2year('1051'))
# Out:
# 2004

# %% [markdown]
# ### the original data frame has no 'year' column

# %%
df
# Out:
#        subj  num suf format         term  code                       inst  \
# 0      NEJS  188   A    LEC    Fall 2004  1043              Levy, Avigdor
# 1      CHEM  121   A    LEC    Fall 2004  1043              Foxman, Bruce
# 2      CHEM  130   A    LEC    Fall 2004  1043                Yu, Jinquan
# 3      COMP    1   A    LEC    Fall 2004  1043             Ruesch, Gordon
# 4       MUS  118   A    STD    Fall 2004  1043                  Ray, Mary
# ...     ...  ...  ..    ...          ...   ...                        ...
# 35201  BIOL   26   A    LEC  Summer 2021  1212  Kosinski-Collins, Melissa
# 35202  ECON   28   B    LEC  Summer 2021  1212         AlMehdar, Mohammed
# 35203  PHIL    1   A    LEC  Summer 2021  1212                Lupu, Peter
# 35204  AAAS  160   B    LEC  Summer 2021  1212         Plumb, Betsy Loren
# 35205   IGS  130   A    LEC  Summer 2021  1212            Campion, Selene
#
#                                                    title sec  enr
# 0                               RISE/DECLINE:OTTOMAN EMP   1   32
# 1                                INORGANIC CHEM I, LECS.   1   18
# 2                               ADV ORG. CHEM: STRUCTURE   1   14
# 3                                            COMPOSITION   3   11
# 4                                       SENIOR RECITAL I   1    3
# ...                                                  ...  ..  ...
# 35201                                      Plant Biology   1    9
# 35202                                 The Global Economy   1    4
# 35203                         Introduction to Philosophy   1    3
# 35204  If We Must Die: War and Military Service in Af...   1    3
# 35205                                   Global Migration   1    1
#
# [35206 rows x 10 columns]

# %% [markdown]
# ### create a new column for the year and the courseid
# We can apply the code2year function to each of the integers in the 'code' column to get a new series,
# and then assign that series to be a new column 'year' of the df dataframe

# %%
cs['year'] = cs['code'].apply(code2year)
cs
# Out:
#        subj  num suf format         term  code                  inst  \
# 63     COSI  171   A    LEC    Fall 2004  1043          Cohn, Martin
# 107    COSI  112   A    LEC    Fall 2004  1043    Pustejovsky, James
# 144    COSI    2   A    LEC    Fall 2004  1043       Hickey, Timothy
# 403    COSI   31   A    LEC    Fall 2004  1043      Cherniack, Mitch
# 492    COSI  215   A    SEM    Fall 2004  1043     Alterman, Richard
# ...     ...  ...  ..    ...          ...   ...                   ...
# 34879  COSI   10   A    LEC    Fall 2020  1203  Tsekourakis, Iraklis
# 34969  COSI   10   A    LEC    Fall 2020  1203       Hickey, Timothy
# 35149  COSI   12   B    LEC  Summer 2021  1212     Golitsyn, Michael
# 35171  COSI  152   A    LEC  Summer 2021  1212       Hickey, Timothy
# 35172  COSI  153   A    LEC  Summer 2021  1212       Hickey, Timothy
#
#                                            title  sec  enr  year
# 63                                    CRYPTOLOGY    1   23  2004
# 107                     THRY/MODELS:INTEL.BEHAVR    1   23  2004
# 144                           INTRO TO COMPUTERS    1   86  2004
# 403                     COMPUTER STRUCTURES/ORG.    1   34  2004
# 492                     ADV.TOPIC:HMAN-CENT COMP    1   10  2004
# ...                                          ...  ...  ...   ...
# 34879  Introduction to Problem Solving in Python    2   67  2020
# 34969  Introduction to Problem Solving in Python  3DL   25  2020
# 35149    Advanced Programming Techniques in Java    1   11  2020
# 35171                Web Application Development    1   18  2020
# 35172             Mobile Application Development    1    9  2020
#
# [589 rows x 11 columns]

# %%
cs['courseid'] = cs['num'].apply(str)+cs['suf']
cs
# Out:
#        subj  num suf format         term  code                  inst  \
# 63     COSI  171   A    LEC    Fall 2004  1043          Cohn, Martin
# 107    COSI  112   A    LEC    Fall 2004  1043    Pustejovsky, James
# 144    COSI    2   A    LEC    Fall 2004  1043       Hickey, Timothy
# 403    COSI   31   A    LEC    Fall 2004  1043      Cherniack, Mitch
# 492    COSI  215   A    SEM    Fall 2004  1043     Alterman, Richard
# ...     ...  ...  ..    ...          ...   ...                   ...
# 34879  COSI   10   A    LEC    Fall 2020  1203  Tsekourakis, Iraklis
# 34969  COSI   10   A    LEC    Fall 2020  1203       Hickey, Timothy
# 35149  COSI   12   B    LEC  Summer 2021  1212     Golitsyn, Michael
# 35171  COSI  152   A    LEC  Summer 2021  1212       Hickey, Timothy
# 35172  COSI  153   A    LEC  Summer 2021  1212       Hickey, Timothy
#
#                                            title  sec  enr  year courseid
# 63                                    CRYPTOLOGY    1   23  2004     171A
# 107                     THRY/MODELS:INTEL.BEHAVR    1   23  2004     112A
# 144                           INTRO TO COMPUTERS    1   86  2004       2A
# 403                     COMPUTER STRUCTURES/ORG.    1   34  2004      31A
# 492                     ADV.TOPIC:HMAN-CENT COMP    1   10  2004     215A
# ...                                          ...  ...  ...   ...      ...
# 34879  Introduction to Problem Solving in Python    2   67  2020      10A
# 34969  Introduction to Problem Solving in Python  3DL   25  2020      10A
# 35149    Advanced Programming Techniques in Java    1   11  2020      12B
# 35171                Web Application Development    1   18  2020     152A
# 35172             Mobile Application Development    1    9  2020     153A
#
# [589 rows x 12 columns]

# %%
cs
# Out:
#        subj  num suf format         term  code                  inst  \
# 63     COSI  171   A    LEC    Fall 2004  1043          Cohn, Martin
# 107    COSI  112   A    LEC    Fall 2004  1043    Pustejovsky, James
# 144    COSI    2   A    LEC    Fall 2004  1043       Hickey, Timothy
# 403    COSI   31   A    LEC    Fall 2004  1043      Cherniack, Mitch
# 492    COSI  215   A    SEM    Fall 2004  1043     Alterman, Richard
# ...     ...  ...  ..    ...          ...   ...                   ...
# 34879  COSI   10   A    LEC    Fall 2020  1203  Tsekourakis, Iraklis
# 34969  COSI   10   A    LEC    Fall 2020  1203       Hickey, Timothy
# 35149  COSI   12   B    LEC  Summer 2021  1212     Golitsyn, Michael
# 35171  COSI  152   A    LEC  Summer 2021  1212       Hickey, Timothy
# 35172  COSI  153   A    LEC  Summer 2021  1212       Hickey, Timothy
#
#                                            title  sec  enr  year courseid
# 63                                    CRYPTOLOGY    1   23  2004     171A
# 107                     THRY/MODELS:INTEL.BEHAVR    1   23  2004     112A
# 144                           INTRO TO COMPUTERS    1   86  2004       2A
# 403                     COMPUTER STRUCTURES/ORG.    1   34  2004      31A
# 492                     ADV.TOPIC:HMAN-CENT COMP    1   10  2004     215A
# ...                                          ...  ...  ...   ...      ...
# 34879  Introduction to Problem Solving in Python    2   67  2020      10A
# 34969  Introduction to Problem Solving in Python  3DL   25  2020      10A
# 35149    Advanced Programming Techniques in Java    1   11  2020      12B
# 35171                Web Application Development    1   18  2020     152A
# 35172             Mobile Application Development    1    9  2020     153A
#
# [589 rows x 12 columns]

# %% [markdown]
# # Group by the year and subject
# This creates a new Series with a multi-index containing both year and subject

# %%
cs_enr = cs.groupby('year')['enr'].agg(sum)
cs_enr.plot()
plt.axis([2004,2021,0,2500])
plt.grid()

# %%
classes_enr = cs.groupby(['courseid','year'])['enr'].agg(sum)
classes_enr
# Out:
# courseid  year
# 101A      2006     22
#           2007     32
#           2008     19
#           2009     19
#           2010     27
#                  ...
# 65A       2013     54
#           2014    142
# 89AJ      2010      1
#           2011      4
#           2012      1
# Name: enr, Length: 511, dtype: int64

# %%
classes_enr = classes_enr.reset_index(level=['courseid'])
classes_enr
# Out:
#      courseid  enr
# year
# 2006     101A   22
# 2007     101A   32
# 2008     101A   19
# 2009     101A   19
# 2010     101A   27
# ...       ...  ...
# 2013      65A   54
# 2014      65A  142
# 2010     89AJ    1
# 2011     89AJ    4
# 2012     89AJ    1
#
# [511 rows x 2 columns]

# %% [markdown]
# # Create a Pivot table of enrollments by classes and year
# Now we do the usual construction of a pivot table

# %%
classes_pt =  pd.pivot_table(classes_enr, values='enr', index=["year"], columns=["courseid"])
classes_pt
# Out:
# courseid  101A  102A  105B    10A  111A  112A  113B  114A  114B  115BJ  ...  \
# year                                                                    ...
# 2004       NaN   NaN   NaN    NaN   NaN  23.0   NaN   NaN   NaN    NaN  ...
# 2005       NaN   NaN   NaN    NaN  28.0   NaN   NaN   NaN  22.0    NaN  ...
# 2006      22.0   NaN   NaN    NaN   NaN  19.0  12.0   NaN   NaN    NaN  ...
# 2007      32.0   NaN   NaN    NaN  10.0   NaN   NaN   NaN  14.0    NaN  ...
# 2008      19.0   NaN   NaN    NaN   NaN  14.0  17.0   NaN   NaN    NaN  ...
# 2009      19.0   NaN   NaN    NaN   NaN   NaN   7.0   NaN  16.0    NaN  ...
# 2010      27.0   NaN   NaN    NaN  12.0   9.0   NaN   NaN  16.0    NaN  ...
# 2011       NaN   NaN   NaN    NaN   NaN   NaN  10.0   NaN  16.0    NaN  ...
# 2012      37.0   NaN   NaN    NaN   NaN   NaN   NaN   NaN  32.0    NaN  ...
# 2013      30.0   NaN   NaN    NaN   NaN  22.0  18.0   NaN  21.0   17.0  ...
# 2014       NaN   NaN  28.0    NaN   NaN   NaN   NaN   NaN  19.0   17.0  ...
# 2015      37.0   NaN  19.0    NaN  23.0   NaN  44.0   NaN  25.0   23.0  ...
# 2016      55.0   NaN  15.0    NaN   NaN  10.0   NaN   NaN  22.0   19.0  ...
# 2017      39.0   NaN  19.0    NaN  17.0   NaN   NaN   NaN  27.0   18.0  ...
# 2018      42.0   NaN  12.0    NaN   NaN  28.0   NaN   NaN  48.0    NaN  ...
# 2019      63.0  47.0   8.0  454.0   NaN   NaN   NaN   NaN  51.0    NaN  ...
# 2020      30.0  47.0   NaN  334.0   NaN   NaN   NaN  84.0  33.0    NaN  ...
#
# courseid     2A   30A   31A  320A  320B   33B   35A   45A    65A  89AJ
# year
# 2004       86.0  23.0  34.0   NaN   NaN  45.0  26.0   NaN    NaN   NaN
# 2005       85.0  16.0  18.0   NaN   NaN  24.0  20.0   NaN    NaN   NaN
# 2006       64.0  15.0  15.0   NaN   NaN  23.0   NaN   NaN   65.0   NaN
# 2007       66.0  21.0  29.0   NaN   NaN  24.0   NaN   NaN    NaN   NaN
# 2008       96.0  20.0  13.0   NaN   NaN  25.0   NaN   NaN    NaN   NaN
# 2009        NaN  21.0  20.0   NaN   NaN   NaN   NaN   NaN   99.0   NaN
# 2010       95.0  18.0  42.0   NaN   NaN   NaN   NaN   NaN    NaN   1.0
# 2011       89.0  13.0  35.0   6.0   3.0   NaN   NaN   NaN   77.0   4.0
# 2012      101.0  41.0  18.0  11.0   6.0   NaN   NaN   NaN    NaN   1.0
# 2013        NaN  34.0  57.0   2.0   NaN   NaN   NaN   NaN   54.0   NaN
# 2014      108.0  75.0   NaN   NaN   1.0   NaN   NaN   NaN  142.0   NaN
# 2015        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2016      158.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2017        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2018        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2019        NaN   NaN   NaN   NaN   NaN   NaN   NaN  10.0    NaN   NaN
# 2020        NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.0    NaN   NaN
#
# [17 rows x 93 columns]

# %% [markdown]
# classes_pt['CS0'] = classes_pt['2A'].fillna(0)+ classes_pt['10A'].fillna(0)+ classes_pt['11A'].fillna(0)# Plot selected columns of the pivot table
# We can now select a few columns and plot them!

# %%
classes_pt['CS0'] = classes_pt['2A'].fillna(0)+ classes_pt['10A'].fillna(0)+ classes_pt['11A'].fillna(0)
classes_pt['31'] = classes_pt['31A'].fillna(0) + classes_pt['131A'].fillna(0)
classes_pt['30'] = classes_pt['30A'].fillna(0) + classes_pt['130A'].fillna(0)
classes_pt['64'] = classes_pt['65A'].fillna(0) + classes_pt['164A'].fillna(0)
classes_pt['core']=classes_pt['CS0']+classes_pt['21A']+classes_pt['29A']+classes_pt['30']+classes_pt['31']+classes_pt['12B']

# %%
classes_pt[['CS0','12B','21A','29A','31','30']].plot(figsize=(15,10))
plt.legend()
plt.grid()
plt.title('Total number of students who have taken classes, by year')
# Out:
# Text(0.5, 1.0, 'Total number of students who have taken classes, by year')

# %%
classes_pt[['CS0','12B','21A','29A','31','30','64']].cumsum().plot(figsize=(15,10))
plt.legend()
plt.grid()
plt.title('Total number of students who have taken classes, by year')
# Out:
# Text(0.5, 1.0, 'Total number of students who have taken classes, by year')

# %% [markdown]
# ## Most popular Computer Science courses at Brandeis

# %%
classes_pt
# Out:
# courseid  101A  102A  105B    10A  111A  112A  113B  114A  114B  115BJ  ...  \
# year                                                                    ...
# 2004       NaN   NaN   NaN    NaN   NaN  23.0   NaN   NaN   NaN    NaN  ...
# 2005       NaN   NaN   NaN    NaN  28.0   NaN   NaN   NaN  22.0    NaN  ...
# 2006      22.0   NaN   NaN    NaN   NaN  19.0  12.0   NaN   NaN    NaN  ...
# 2007      32.0   NaN   NaN    NaN  10.0   NaN   NaN   NaN  14.0    NaN  ...
# 2008      19.0   NaN   NaN    NaN   NaN  14.0  17.0   NaN   NaN    NaN  ...
# 2009      19.0   NaN   NaN    NaN   NaN   NaN   7.0   NaN  16.0    NaN  ...
# 2010      27.0   NaN   NaN    NaN  12.0   9.0   NaN   NaN  16.0    NaN  ...
# 2011       NaN   NaN   NaN    NaN   NaN   NaN  10.0   NaN  16.0    NaN  ...
# 2012      37.0   NaN   NaN    NaN   NaN   NaN   NaN   NaN  32.0    NaN  ...
# 2013      30.0   NaN   NaN    NaN   NaN  22.0  18.0   NaN  21.0   17.0  ...
# 2014       NaN   NaN  28.0    NaN   NaN   NaN   NaN   NaN  19.0   17.0  ...
# 2015      37.0   NaN  19.0    NaN  23.0   NaN  44.0   NaN  25.0   23.0  ...
# 2016      55.0   NaN  15.0    NaN   NaN  10.0   NaN   NaN  22.0   19.0  ...
# 2017      39.0   NaN  19.0    NaN  17.0   NaN   NaN   NaN  27.0   18.0  ...
# 2018      42.0   NaN  12.0    NaN   NaN  28.0   NaN   NaN  48.0    NaN  ...
# 2019      63.0  47.0   8.0  454.0   NaN   NaN   NaN   NaN  51.0    NaN  ...
# 2020      30.0  47.0   NaN  334.0   NaN   NaN   NaN  84.0  33.0    NaN  ...
#
# courseid   33B   35A   45A    65A  89AJ    CS0     31     30     64    core
# year
# 2004      45.0  26.0   NaN    NaN   NaN  127.0   34.0   23.0    0.0     NaN
# 2005      24.0  20.0   NaN    NaN   NaN  139.0   18.0   16.0    0.0     NaN
# 2006      23.0   NaN   NaN   65.0   NaN  100.0   15.0   15.0   65.0     NaN
# 2007      24.0   NaN   NaN    NaN   NaN  134.0   29.0   21.0    0.0     NaN
# 2008      25.0   NaN   NaN    NaN   NaN  180.0   13.0   20.0    0.0     NaN
# 2009       NaN   NaN   NaN   99.0   NaN  117.0   20.0   21.0   99.0   273.0
# 2010       NaN   NaN   NaN    NaN   1.0  183.0   42.0   18.0    0.0   337.0
# 2011       NaN   NaN   NaN   77.0   4.0  219.0   35.0   13.0   77.0   409.0
# 2012       NaN   NaN   NaN    NaN   1.0  277.0   18.0   73.0    0.0   617.0
# 2013       NaN   NaN   NaN   54.0   NaN  230.0   57.0   65.0   54.0   691.0
# 2014       NaN   NaN   NaN  142.0   NaN  413.0  104.0   75.0  142.0  1042.0
# 2015       NaN   NaN   NaN    NaN   NaN  304.0  103.0   81.0    0.0   881.0
# 2016       NaN   NaN   NaN    NaN   NaN  434.0  107.0   79.0  126.0  1156.0
# 2017       NaN   NaN   NaN    NaN   NaN  270.0  132.0   61.0    0.0   916.0
# 2018       NaN   NaN   NaN    NaN   NaN  415.0  118.0   85.0  201.0  1195.0
# 2019       NaN   NaN  10.0    NaN   NaN  454.0  191.0  101.0    0.0  1370.0
# 2020       NaN   NaN   8.0    NaN   NaN  334.0  172.0   87.0  166.0  1111.0
#
# [17 rows x 98 columns]

# %%
df2 = cs[cs['code']>1042]
courses = df2.groupby(['courseid','title'])['enr'].agg(sum)
courses.sort_values(inplace=True, ascending=False)
courses
# Out:
# courseid  title
# 11A       PROGRAMMING:JAVA AND C                           2179
# 12B       ADV. PROGRAMMING TECHNIQUES                      1645
# 21A       STRUCTURE/FUNDMT.COMPUT.                         1549
# 29A       DISCRETE STRUCTURES                               981
# 2A        INTRO TO COMPUTERS                                948
#                                                            ...
# 89AJ      RESEARCH INTERNSHIP                                 6
# 138A      Computational Linguistics Second Year Seminar       5
# 232F      COMPUTATIONAL MODELS DISCOURSE                      5
# 233F      DIALOG MANAGEMENT SYSTEMS                           3
# 233A      DISCOURSE AND DIALOG                                3
# Name: enr, Length: 145, dtype: int64

# %%
fac = cs.groupby('courseid')
fac = fac['enr'].agg([sum])
fac = fac.sort_values(ascending=False, by='sum').head(40)
fac
# Out:
#            sum
# courseid
# 11A       2594
# 12B       1882
# 21A       1750
# 29A       1082
# 2A         948
# 131A       927
# 10A        788
# 127B       679
# 130A       557
# 164A       493
# 177A       461
# 101A       452
# 65A        437
# 121B       380
# 114B       362
# 125A       361
# 21B        340
# 123A       316
# 30A        297
# 118A       293
# 180A       289
# 133B       289
# 31A        281
# 155B       262
# 134A       243
# 153A       216
# 166B       211
# 175A       203
# 132A       183
# 129A       162
# 178A       159
# 165A       159
# 154AJ      159
# 137B       156
# 152AJ      144
# 140B       142
# 33B        141
# 22A        134
# 167B       133
# 216A       130

# %%
pc1 = cs.groupby('courseid')['inst'].agg(list).sort_values(ascending=False)
pc2 = pc1.apply(lambda x: len(x))
pc = pd.DataFrame([pc1,pc2])
pc
# Out:
# courseid            165B            241A  \
# inst      [Zhang, Chuxu]  [Zhang, Chuxu]
# inst                   1               1
#
# courseid                                               137B  \
# inst      [Xue, Nianwen, Xue, Nianwen, Xue, Nianwen, Xue...
# inst                                                      9
#
# courseid                                         45A  \
# inst      [Wittenberg, William, Wittenberg, William]
# inst                                               2
#
# courseid                                                11A  \
# inst      [Wittenberg, David, Hickey, Timothy, Hickey, T...
# inst                                                     32
#
# courseid                                               134A  \
# inst      [Wellner, Benjamin, Wellner, Benjamin, Wellner...
# inst                                                     12
#
# courseid                     139A  \
# inst      [Tresner-Kirsch, David]
# inst                            1
#
# courseid                                               175A  \
# inst      [Storer, James, Storer, James, Storer, James, ...
# inst                                                      8
#
# courseid                                               180A  \
# inst      [Storer, James, Storer, James, Storer, James, ...
# inst                                                      8
#
# courseid                                                21A  ...  \
# inst      [Storer, James, Storer, James, Storer, James, ...  ...
# inst                                                     30  ...
#
# courseid                                               128A  \
# inst      [Cherniack, Mitch, Cherniack, Mitch, Cherniack...
# inst                                                      3
#
# courseid                                  227B  \
# inst      [Cherniack, Mitch, Cherniack, Mitch]
# inst                                         2
#
# courseid                                               153A  \
# inst      [Chaturvedi, Praveen, Chaturvedi, Praveen, Cha...
# inst                                                      5
#
# courseid                                               132A  \
# inst      [Anick, Peter, Anick, Peter, Anick, Peter, Ani...
# inst                                                      8
#
# courseid                                               118A  \
# inst      [Alterman, Richard, Alterman, Richard, Alterma...
# inst                                                      8
#
# courseid                                               125A  \
# inst      [Alterman, Richard, Alterman, Richard, Alterma...
# inst                                                      7
#
# courseid                                               111A  \
# inst      [Alterman, Richard, Alterman, Richard, Alterma...
# inst                                                      5
#
# courseid                                               215A  \
# inst      [Alterman, Richard, Alterman, Richard, Alterma...
# inst                                                      4
#
# courseid                                    139B                  25A
# inst      [Alterman, Richard, Alterman, Richard]  [Alterman, Richard]
# inst                                           2                    1
#
# [2 rows x 93 columns]

# %%
inst_enr = cs.groupby(['inst','year'])['enr'].agg(sum)
inst_enr
# Out:
# inst                year
# Abi-Antoun, Marwan  2019    40
# Alterman, Richard   2004    40
#                     2005    52
#                     2006    31
#                     2007    10
#                             ..
# Xue, Nianwen        2018    56
#                     2019    74
#                     2020    42
# Zhang, Chuxu        2020    26
# Zimmerman, Grace    2018    18
# Name: enr, Length: 276, dtype: int64

# %%
inst_enr = inst_enr.reset_index(level=['inst'])
inst_enr
# Out:
#                     inst  enr
# year
# 2019  Abi-Antoun, Marwan   40
# 2004   Alterman, Richard   40
# 2005   Alterman, Richard   52
# 2006   Alterman, Richard   31
# 2007   Alterman, Richard   10
# ...                  ...  ...
# 2018        Xue, Nianwen   56
# 2019        Xue, Nianwen   74
# 2020        Xue, Nianwen   42
# 2020        Zhang, Chuxu   26
# 2018    Zimmerman, Grace   18
#
# [276 rows x 2 columns]

# %%
inst_pt =  pd.pivot_table(inst_enr, values='enr', index=["year"], columns=["inst"])
inst_pt
# Out:
# inst  Abi-Antoun, Marwan  Alterman, Richard  Anick, Peter  Anick, Peter G  \
# year
# 2004                 NaN               40.0           NaN             NaN
# 2005                 NaN               52.0           NaN             NaN
# 2006                 NaN               31.0           NaN             NaN
# 2007                 NaN               10.0           NaN             NaN
# 2008                 NaN               51.0           NaN             NaN
# 2009                 NaN               36.0           NaN             NaN
# 2010                 NaN               20.0           NaN             NaN
# 2011                 NaN              151.0           NaN             NaN
# 2012                 NaN               17.0          12.0             NaN
# 2013                 NaN               66.0          18.0             NaN
# 2014                 NaN              179.0          25.0             NaN
# 2015                 NaN               82.0          25.0             NaN
# 2016                 NaN               42.0          23.0             NaN
# 2017                 NaN              110.0           8.0             NaN
# 2018                 NaN               99.0          25.0             NaN
# 2019                40.0               53.0          27.0             NaN
# 2020                 NaN               61.0           NaN            32.0
#
# inst  Chaturvedi, Praveen  Cherniack, Mitch  Cohen, Jacques  Cohn, Martin  \
# year
# 2004                  NaN              63.0            15.0          46.0
# 2005                  NaN              18.0            10.0           NaN
# 2006                  NaN              35.0            19.0           NaN
# 2007                  NaN              40.0             NaN           NaN
# 2008                  NaN              44.0             NaN           NaN
# 2009                  NaN              56.0             NaN           NaN
# 2010                  NaN              72.0             NaN           NaN
# 2011                  NaN              73.0             NaN           NaN
# 2012                  NaN              41.0             NaN           NaN
# 2013                 87.0             144.0             NaN           NaN
# 2014                 61.0             137.0             NaN           NaN
# 2015                 52.0             103.0             NaN           NaN
# 2016                112.0             203.0             NaN           NaN
# 2017                  NaN             171.0             NaN           NaN
# 2018                  NaN               NaN             NaN           NaN
# 2019                  NaN             246.0             NaN           NaN
# 2020                  NaN             101.0             NaN           NaN
#
# inst  Colon Osorio, Fernando  DiLillo, Antonella  ...  Storer, James  \
# year                                              ...
# 2004                     NaN                 NaN  ...           73.0
# 2005                     NaN                 NaN  ...           93.0
# 2006                     NaN                 NaN  ...           64.0
# 2007                     NaN               163.0  ...           14.0
# 2008                     NaN               152.0  ...           36.0
# 2009                    15.0               150.0  ...           38.0
# 2010                    30.0               201.0  ...           45.0
# 2011                    50.0               319.0  ...           50.0
# 2012                    64.0               290.0  ...          121.0
# 2013                     NaN               499.0  ...           73.0
# 2014                     NaN               213.0  ...          126.0
# 2015                     NaN               525.0  ...          135.0
# 2016                     NaN               458.0  ...          157.0
# 2017                     NaN               308.0  ...          100.0
# 2018                     NaN               476.0  ...          121.0
# 2019                     NaN               603.0  ...           62.0
# 2020                     NaN               340.0  ...          100.0
#
# inst  Tresner-Kirsch, David  Tsekourakis, Iraklis  Verhagen, Marcus E.  \
# year
# 2004                    NaN                   NaN                  NaN
# 2005                    NaN                   NaN                  NaN
# 2006                    NaN                   NaN                  NaN
# 2007                    NaN                   NaN                  NaN
# 2008                    NaN                   NaN                  NaN
# 2009                    NaN                   NaN                  NaN
# 2010                    NaN                   NaN                  NaN
# 2011                   19.0                   NaN                  NaN
# 2012                    NaN                   NaN                  NaN
# 2013                    6.0                   NaN                  NaN
# 2014                    NaN                   NaN                  NaN
# 2015                    NaN                   NaN                  NaN
# 2016                    NaN                   NaN                  NaN
# 2017                    NaN                   NaN                  NaN
# 2018                    NaN                   NaN                  NaN
# 2019                    NaN                  17.0                  NaN
# 2020                    NaN                 305.0                  5.0
#
# inst  Wellner, Benjamin  Wittenberg, David  Wittenberg, William  Xue, Nianwen  \
# year
# 2004                NaN               39.0                  NaN           NaN
# 2005                NaN               16.0                  NaN           NaN
# 2006                NaN               15.0                  NaN           NaN
# 2007                NaN                NaN                  NaN           NaN
# 2008                NaN                NaN                  NaN           5.0
# 2009                8.0                NaN                  NaN           7.0
# 2010               10.0                NaN                  NaN           8.0
# 2011               13.0                NaN                  NaN           NaN
# 2012               13.0                NaN                  NaN          16.0
# 2013               13.0                NaN                  NaN          12.0
# 2014               29.0                NaN                  NaN          15.0
# 2015               15.0                NaN                  NaN          15.0
# 2016               30.0                NaN                  NaN           NaN
# 2017                NaN                NaN                  NaN          52.0
# 2018               18.0                NaN                  NaN          56.0
# 2019               33.0                NaN                 10.0          74.0
# 2020               15.0                NaN                  8.0          42.0
#
# inst  Zhang, Chuxu  Zimmerman, Grace
# year
# 2004           NaN               NaN
# 2005           NaN               NaN
# 2006           NaN               NaN
# 2007           NaN               NaN
# 2008           NaN               NaN
# 2009           NaN               NaN
# 2010           NaN               NaN
# 2011           NaN               NaN
# 2012           NaN               NaN
# 2013           NaN               NaN
# 2014           NaN               NaN
# 2015           NaN               NaN
# 2016           NaN               NaN
# 2017           NaN               NaN
# 2018           NaN              18.0
# 2019           NaN               NaN
# 2020          26.0               NaN
#
# [17 rows x 44 columns]

# %%
print("COSI instructors ranked by number of student taught")
insts.index
# Out:
# COSI instructors ranked by number of student taught
# Index(['DiLillo, Antonella', 'Hickey, Timothy', 'Cherniack, Mitch',
#        'Tsekourakis, Iraklis', 'Papaemmanouil, Olga', 'Salas, R. Pito',
#        'Hong, Pengyu', 'Storer, James', 'Mairson, Harry',
#        'Lignos, Constantine', 'Pustejovsky, James', 'Pollack, Jordan',
#        'Liu, Hongfu', 'Xue, Nianwen', 'Alterman, Richard', 'Wellner, Benjamin',
#        'Abi-Antoun, Marwan', 'Golitsyn, Michael', 'Anick, Peter G',
#        'Plaster, Keith', 'Anick, Peter', 'Zhang, Chuxu', 'Wittenberg, William',
#        'Meteer, Marie', 'Verhagen, Marcus E.'],
#       dtype='object', name='inst')

# %%
inst_pt[insts.index[:20]].plot(figsize=(15,10))
plt.legend()
plt.grid()
plt.title('Total number of students taught by top 20 faculty faculty,  by year')
#plt.savefig("images/csfacbyyearCUM.png")
# Out:
# Text(0.5, 1.0, 'Total number of students taught by top 20 faculty faculty,  by year')

# %%
insts.index
# Out:
# Index(['DiLillo, Antonella', 'Hickey, Timothy', 'Cherniack, Mitch',
#        'Tsekourakis, Iraklis', 'Papaemmanouil, Olga', 'Salas, R. Pito',
#        'Hong, Pengyu', 'Storer, James', 'Mairson, Harry',
#        'Lignos, Constantine', 'Pustejovsky, James', 'Pollack, Jordan',
#        'Liu, Hongfu', 'Xue, Nianwen', 'Alterman, Richard', 'Wellner, Benjamin',
#        'Abi-Antoun, Marwan', 'Golitsyn, Michael', 'Anick, Peter G',
#        'Plaster, Keith', 'Anick, Peter', 'Zhang, Chuxu', 'Wittenberg, William',
#        'Meteer, Marie', 'Verhagen, Marcus E.'],
#       dtype='object', name='inst')

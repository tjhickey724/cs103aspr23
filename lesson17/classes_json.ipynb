# %% [markdown]
# # Analyzing a JSON dataset in pandas
# In this notebook we look into analyzing the PA01 dataset using Pandas

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### use read_json to read it into a data frame

# %%
df = pd.read_json('data2/classes/courses20-21.json')
df
# Out:
#       limit                                              times  enrolled  \
# 0       NaN                                                 []         0
# 1       NaN                                                 []         0
# 2       NaN                                                 []         0
# 3       NaN                                                 []         0
# 4       NaN                                                 []         0
# ...     ...                                                ...       ...
# 7808    NaN  [{'start': 840, 'days': ['tu', 'th'], 'end': 9...         5
# 7809   15.0                                                 []         4
# 7810    NaN                                                 []         3
# 7811   10.0                                                 []         6
# 7812    NaN                                                 []         1
#
#                                                 details     type  \
# 0     Instructor's Signature Required.\nSee Course C...  section
# 1     Instructor's Signature Required.\nSee Course C...  section
# 2     Instructor's Signature Required.\nSee Course C...  section
# 3     Instructor's Signature Required.\nSee Course C...  section
# 4     Instructor's Signature Required.\nSee Course C...  section
# ...                                                 ...      ...
# 7808                                                     section
# 7809                                                     section
# 7810                                                     section
# 7811                                                     section
# 7812                                                     section
#
#             status_text section  waiting  \
# 0     Open Consent Req.       2        0
# 1     Open Consent Req.       2        0
# 2     Open Consent Req.       2        0
# 3     Open Consent Req.       2        0
# 4     Open Consent Req.       2        0
# ...                 ...     ...      ...
# 7808               Open       1        0
# 7809               Open       1        0
# 7810               Open       1        0
# 7811               Open       2        0
# 7812  Open Consent Req.       1        0
#
#                                              instructor  \
# 0         [Sharon, Feiman-Nemser, snemser@brandeis.edu]
# 1               [Joseph B, Reimer, reimer@brandeis.edu]
# 2                   [Mark, Rosen, mirosen@brandeis.edu]
# 3                 [Jonathan, Sarna, sarna@brandeis.edu]
# 4                  [Ellen, Smith, esmith2@brandeis.edu]
# ...                                                 ...
# 7808              [Peter, Lupu, peterlupu@brandeis.edu]
# 7809           [Selene, Campion, scampion@brandeis.edu]
# 7810         [Nataliia, Laas, natalialaas@brandeis.edu]
# 7811  [Melissa, Kosinski-Collins, kosinski@brandeis....
# 7812             [William, Flesch, flesch@brandeis.edu]
#
#                                  coinstructors          code subject  \
# 0                                           []  [HRNS, 329F]    HRNS
# 1                                           []  [HRNS, 333F]    HRNS
# 2                                           []  [HRNS, 335F]    HRNS
# 3                                           []  [HRNS, 339F]    HRNS
# 4                                           []  [HRNS, 341F]    HRNS
# ...                                        ...           ...     ...
# 7808                                        []    [PHIL, 1A]    PHIL
# 7809                                        []   [IGS, 130A]     IGS
# 7810                                        []  [HIST, 118A]    HIST
# 7811  [[Sumana, Setty, sumana45@brandeis.edu]]   [BISC, 10B]    BISC
# 7812                                        []    [ENG, 98A]     ENG
#
#      coursenum                                        name  independent_study  \
# 0         329F  Readings in Jewish Professional Leadership               True
# 1         333F  Readings in Jewish Professional Leadership               True
# 2         335F  Readings in Jewish Professional Leadership               True
# 3         339F  Readings in Jewish Professional Leadership               True
# 4         341F  Readings in Jewish Professional Leadership               True
# ...        ...                                         ...                ...
# 7808        1A                  Introduction to Philosophy              False
# 7809      130A                            Global Migration              False
# 7810      118A         The History of American Advertising              False
# 7811       10B               The Biology of Women's Health              False
# 7812       98A                           Independent Study               True
#
#       term                                        description
# 0     1203  Meets for one-half semester and yields half-co...
# 1     1203  Meets for one-half semester and yields half-co...
# 2     1203  Meets for one-half semester and yields half-co...
# 3     1203  Meets for one-half semester and yields half-co...
# 4     1203  Meets for one-half semester and yields half-co...
# ...    ...                                                ...
# 7808  1212  Enrollment varies according to instructor. Ref...
# 7809  1212  Investigates the social, cultural, religious, ...
# 7810  1212  Considers American advertising from the eighte...
# 7811  1212  Does not meet the requirements for the major i...
# 7812  1212                 Usually offered every year.\nStaff
#
# [7813 rows x 17 columns]

# %% [markdown]
# ### look at the columms and their types
# Note that some of the types are object, e.g. times is a list of dictionaries, but stored as an object type

# %%
df.dtypes
# Out:
# limit                float64
# times                 object
# enrolled               int64
# details               object
# type                  object
# status_text           object
# section               object
# waiting                int64
# instructor            object
# coinstructors         object
# code                  object
# subject               object
# coursenum             object
# name                  object
# independent_study       bool
# term                   int64
# description           object
# dtype: object

# %% [markdown]
# ### look at all values in some column
# In pure python we used a set comprehension to get the set of subjects, here we can use the .unique() method

# %%
df['subject'].unique()
# Out:
# array(['HRNS', 'BUS', 'ECON', 'FIN', 'HS', 'ANTH', 'CHEM', 'PHIL', 'HIST',
#        'PSYC', 'WGS', 'ENG', 'POL', 'BIOL', 'NBIO', 'CHIN', 'MATH', 'MUS',
#        'SOC', 'BCBP', 'BIOT', 'ED', 'CLAS', 'COMH', 'COSI', 'GRK', 'LAT',
#        'THA', 'PHYS', 'NEJS', 'NEUR', 'PMED', 'ESL', 'BUS/FIN',
#        'BUS/ECON', 'ECON/FIN', 'HS/POL', 'HWL', 'GER', 'JAPN', 'KOR',
#        'RUS', 'ITAL', 'HISP', 'FREN', 'IGS', 'AMST', 'AAAS', 'BCHM',
#        'BIPH', 'EAS', 'COML', 'SAS', 'YDSH', 'SJSP', 'REL', 'PAX', 'LGLS',
#        'QBIO', 'BIBC', 'HSSP', 'ENVS', 'ECS', 'FILM', 'FA', 'HOID', 'IIM',
#        'CAST', 'IMES', 'LALS', 'LING', 'JOUR', 'HBRW', 'NPSY', 'ARBC',
#        'INT', 'CA', 'EBIO', 'AAAS/WGS', 'HUM', 'EL', 'CBIO', 'AMST/ENG',
#        'RECS/THA', 'UWS', 'COMP', 'MERS', 'AAS/AAPI', 'AAPI/HIS', 'RECS',
#        'AAPI/WGS', 'AAAS/HIS', 'BISC', 'AAPI', 'GS', 'POL/WGS', 'HUM/UWS',
#        'CHSC', 'AMST/MUS', 'HIST/SOC', 'QR', 'CLAS/ENG', 'ANTH/WGS',
#        'HIST/WGS', 'CLAS/NEJ', 'ECS/ENG', 'RBIF', 'RBOT', 'RCOM', 'RDFT',
#        'RDMD', 'RHIN', 'RIAS', 'RIDT', 'RMGT', 'RPJM', 'RSAN', 'RSEG',
#        'RUCD', 'GECS'], dtype=object)

# %% [markdown]
# ### select the courses in one department

# %%
df[ df['subject']=='JAPN']
# Out:
#       limit                                              times  enrolled  \
# 1496   18.0  [{'days': ['th', 'w', 'm', 'tu'], 'end': 690, ...         9
# 1497   18.0  [{'start': 600, 'end': 690, 'days': ['w', 'th'...         7
# 1498   15.0  [{'days': ['m', 'w'], 'end': 930, 'start': 840...        16
# 1499   18.0  [{'start': 720, 'end': 810, 'days': ['th', 'w'...        14
# 1500   16.0  [{'end': 810, 'days': ['m', 'tu', 'th', 'w'], ...        17
# 1501   15.0  [{'days': ['w', 'm'], 'end': 1170, 'start': 10...         4
# 1502   18.0  [{'start': 1080, 'days': ['th', 'w', 'm', 'tu'...        16
# 2434    NaN                                                 []         0
# 3234    NaN                                                 []         0
# 3451   30.0  [{'end': 1050, 'days': ['m', 'w'], 'start': 960}]         8
# 5447   18.0  [{'end': 690, 'days': ['m', 'tu', 'th', 'w'], ...        18
# 5448   18.0  [{'start': 600, 'end': 690, 'days': ['th', 'w'...        17
# 5449   18.0  [{'end': 810, 'days': ['th', 'w', 'm', 'tu'], ...        13
# 5450   18.0  [{'start': 720, 'end': 810, 'days': ['tu', 'm'...        19
# 5451   18.0  [{'days': ['th', 'w', 'm', 'tu'], 'end': 930, ...        19
# 5452   18.0  [{'start': 1080, 'end': 1170, 'days': ['tu', '...        10
# 5453   18.0  [{'start': 840, 'days': ['w', 'm'], 'end': 930...        19
# 5454   15.0  [{'building': 'Lown Cntr for JudaicStudies', '...         3
# 6328    NaN                                                 []         0
# 7202   28.0  [{'days': ['w', 'm'], 'end': 1170, 'building':...        12
# 7203   28.0  [{'end': 1050, 'days': ['m', 'w'], 'room': '20...         6
#
#                                                 details     type  \
# 1496  See Course Catalog for prerequisites.\nInstruc...  section
# 1497  See Course Catalog for prerequisites.\nInstruc...  section
# 1498  See Course Catalog for prerequisites.\nInstruc...  section
# 1499  See Course Catalog for prerequisites.\nInstruc...  section
# 1500  See Course Catalog for prerequisites.\nInstruc...  section
# 1501  See Course Catalog for prerequisites.\nInstruc...  section
# 1502  See Course Catalog for prerequisites.\nInstruc...  section
# 2434  Instructor's Signature Required.\nTo register ...  section
# 3234  Instructor's Signature Required.\nTo register ...  section
# 3451  Instruction for this course will be offered in...  section
# 5447  Class meets for 50 minutes 4 days per week dur...  section
# 5448  See Course Catalog for Special Notes.\nSee Cou...  section
# 5449  See Course Catalog for Special Notes.\nClass m...  section
# 5450  Instruction for this course will be offered in...  section
# 5451  See Course Catalog for Special Notes.\nClass m...  section
# 5452  See Course Catalog for Special Notes.\nClass m...  section
# 5453  See Course Catalog for prerequisites.\nInstruc...  section
# 5454  See Course Catalog for prerequisites.\nUnaccom...  section
# 6328  Instructor's Signature Required.\nTo register ...  section
# 7202  Instruction for this course will be offered in...  section
# 7203  Instruction for this course will be offered in...  section
#
#               status_text section  waiting  \
# 1496                 Open       1        0
# 1497                 Open       1        0
# 1498  Closed Consent Req.       1        0
# 1499               Closed       2        1
# 1500  Closed Consent Req.       2        0
# 1501                 Open       1        0
# 1502                 Open       3        0
# 2434    Open Consent Req.       1        0
# 3234    Open Consent Req.       2        0
# 3451                 Open       1        0
# 5447               Closed       1        0
# 5448               Closed       1        0
# 5449                 Open       2        0
# 5450               Closed       2        0
# 5451               Closed       3        0
# 5452                 Open       4        0
# 5453  Closed Consent Req.       1        0
# 5454                 Open       1        0
# 6328    Open Consent Req.       1        0
# 7202                 Open       1        0
# 7203                 Open       1        0
#
#                                              instructor coinstructors  \
# 1496  [Yukiko, Takahashi, yukikotakahashi@brandeis.edu]            []
# 1497              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 1498              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 1499  [Yukiko, Takahashi, yukikotakahashi@brandeis.edu]            []
# 1500              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 1501         [Matthew, Fraleigh, fraleigh@brandeis.edu]            []
# 1502             [Mayumi, Tamaki, mtamaki@brandeis.edu]            []
# 2434           [Hisae, Fujiwara, hfujiwar@brandeis.edu]            []
# 3234              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 3451         [Matthew, Fraleigh, fraleigh@brandeis.edu]            []
# 5447           [Hisae, Fujiwara, hfujiwar@brandeis.edu]            []
# 5448              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 5449           [Hisae, Fujiwara, hfujiwar@brandeis.edu]            []
# 5450              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 5451           [Hisae, Fujiwara, hfujiwar@brandeis.edu]            []
# 5452             [Mayumi, Tamaki, mtamaki@brandeis.edu]            []
# 5453              [Yukimi, Nakano, yukimi@brandeis.edu]            []
# 5454           [Hisae, Fujiwara, hfujiwar@brandeis.edu]            []
# 6328           [Hisae, Fujiwara, hfujiwar@brandeis.edu]            []
# 7202         [Matthew, Fraleigh, fraleigh@brandeis.edu]            []
# 7203         [Matthew, Fraleigh, fraleigh@brandeis.edu]            []
#
#               code subject coursenum  \
# 1496   [JAPN, 20B]    JAPN       20B
# 1497   [JAPN, 40B]    JAPN       40B
# 1498  [JAPN, 105B]    JAPN      105B
# 1499   [JAPN, 20B]    JAPN       20B
# 1500   [JAPN, 40B]    JAPN       40B
# 1501  [JAPN, 120B]    JAPN      120B
# 1502   [JAPN, 20B]    JAPN       20B
# 2434   [JAPN, 98B]    JAPN       98B
# 3234   [JAPN, 98B]    JAPN       98B
# 3451  [JAPN, 140A]    JAPN      140A
# 5447   [JAPN, 10A]    JAPN       10A
# 5448   [JAPN, 30A]    JAPN       30A
# 5449   [JAPN, 10A]    JAPN       10A
# 5450   [JAPN, 30A]    JAPN       30A
# 5451   [JAPN, 10A]    JAPN       10A
# 5452   [JAPN, 10A]    JAPN       10A
# 5453  [JAPN, 105A]    JAPN      105A
# 5454  [JAPN, 120A]    JAPN      120A
# 6328   [JAPN, 98A]    JAPN       98A
# 7202  [JAPN, 125B]    JAPN      125B
# 7203  [JAPN, 145A]    JAPN      145A
#
#                                                    name  independent_study  \
# 1496                                Continuing Japanese              False
# 1497                     Advanced Intermediate Japanese              False
# 1498           Advanced Conversation and Composition II              False
# 1499                                Continuing Japanese              False
# 1500                     Advanced Intermediate Japanese              False
# 1501             Readings in Modern Japanese Literature              False
# 1502                                Continuing Japanese              False
# 2434                               Readings in Japanese               True
# 3234                               Readings in Japanese               True
# 3451      The World of Early Modern Japanese Literature              False
# 5447                                 Beginning Japanese              False
# 5448                              Intermediate Japanese              False
# 5449                                 Beginning Japanese              False
# 5450                              Intermediate Japanese              False
# 5451                                 Beginning Japanese              False
# 5452                                 Beginning Japanese              False
# 5453            Advanced Conversation and Composition I              False
# 5454  Topics in Contemporary Japanese Culture and So...              False
# 6328                               Readings in Japanese               True
# 7202  Putting Away Childish Things: Coming of Age in...              False
# 7203         The World of Classical Japanese Literature              False
#
#       term                                        description
# 1496  1211  Prerequisite: A grade of C- or higher in JAPN ...
# 1497  1211  Prerequisite: A grade of C- or higher in JAPN ...
# 1498  1211  Prerequisite: A grade of C- or higher in JAPN ...
# 1499  1211  Prerequisite: A grade of C- or higher in JAPN ...
# 1500  1211  Prerequisite: A grade of C- or higher in JAPN ...
# 1501  1211  Prerequisite: JAPN 120a or the equivalent.\n\n...
# 1502  1211  Prerequisite: A grade of C- or higher in JAPN ...
# 2434  1211  May be taken only with the permission of the C...
# 3234  1211  May be taken only with the permission of the C...
# 3451  1211  A survey of the most celebrated works of liter...
# 5447  1203  Meets four days per week for a total of four c...
# 5448  1203  Prerequisite: A grade of C- or higher in JAPN ...
# 5449  1203  Meets four days per week for a total of four c...
# 5450  1203  Prerequisite: A grade of C- or higher in JAPN ...
# 5451  1203  Meets four days per week for a total of four c...
# 5452  1203  Meets four days per week for a total of four c...
# 5453  1203  Prerequisite: A grade of C- or higher in JAPN ...
# 5454  1203  Prerequisite: A grade of C- or higher in JAPN ...
# 6328  1203  May be taken only with the permission of the C...
# 7202  1203  Explores the ways in which modern Japanese wri...
# 7203  1203  A survey of some of the most important works o...

# %%
df
# Out:
#       limit                                              times  enrolled  \
# 0       NaN                                                 []         0
# 1       NaN                                                 []         0
# 2       NaN                                                 []         0
# 3       NaN                                                 []         0
# 4       NaN                                                 []         0
# ...     ...                                                ...       ...
# 7808    NaN  [{'start': 840, 'days': ['tu', 'th'], 'end': 9...         5
# 7809   15.0                                                 []         4
# 7810    NaN                                                 []         3
# 7811   10.0                                                 []         6
# 7812    NaN                                                 []         1
#
#                                                 details     type  \
# 0     Instructor's Signature Required.\nSee Course C...  section
# 1     Instructor's Signature Required.\nSee Course C...  section
# 2     Instructor's Signature Required.\nSee Course C...  section
# 3     Instructor's Signature Required.\nSee Course C...  section
# 4     Instructor's Signature Required.\nSee Course C...  section
# ...                                                 ...      ...
# 7808                                                     section
# 7809                                                     section
# 7810                                                     section
# 7811                                                     section
# 7812                                                     section
#
#             status_text section  waiting  \
# 0     Open Consent Req.       2        0
# 1     Open Consent Req.       2        0
# 2     Open Consent Req.       2        0
# 3     Open Consent Req.       2        0
# 4     Open Consent Req.       2        0
# ...                 ...     ...      ...
# 7808               Open       1        0
# 7809               Open       1        0
# 7810               Open       1        0
# 7811               Open       2        0
# 7812  Open Consent Req.       1        0
#
#                                              instructor  \
# 0         [Sharon, Feiman-Nemser, snemser@brandeis.edu]
# 1               [Joseph B, Reimer, reimer@brandeis.edu]
# 2                   [Mark, Rosen, mirosen@brandeis.edu]
# 3                 [Jonathan, Sarna, sarna@brandeis.edu]
# 4                  [Ellen, Smith, esmith2@brandeis.edu]
# ...                                                 ...
# 7808              [Peter, Lupu, peterlupu@brandeis.edu]
# 7809           [Selene, Campion, scampion@brandeis.edu]
# 7810         [Nataliia, Laas, natalialaas@brandeis.edu]
# 7811  [Melissa, Kosinski-Collins, kosinski@brandeis....
# 7812             [William, Flesch, flesch@brandeis.edu]
#
#                                  coinstructors          code subject  \
# 0                                           []  [HRNS, 329F]    HRNS
# 1                                           []  [HRNS, 333F]    HRNS
# 2                                           []  [HRNS, 335F]    HRNS
# 3                                           []  [HRNS, 339F]    HRNS
# 4                                           []  [HRNS, 341F]    HRNS
# ...                                        ...           ...     ...
# 7808                                        []    [PHIL, 1A]    PHIL
# 7809                                        []   [IGS, 130A]     IGS
# 7810                                        []  [HIST, 118A]    HIST
# 7811  [[Sumana, Setty, sumana45@brandeis.edu]]   [BISC, 10B]    BISC
# 7812                                        []    [ENG, 98A]     ENG
#
#      coursenum                                        name  independent_study  \
# 0         329F  Readings in Jewish Professional Leadership               True
# 1         333F  Readings in Jewish Professional Leadership               True
# 2         335F  Readings in Jewish Professional Leadership               True
# 3         339F  Readings in Jewish Professional Leadership               True
# 4         341F  Readings in Jewish Professional Leadership               True
# ...        ...                                         ...                ...
# 7808        1A                  Introduction to Philosophy              False
# 7809      130A                            Global Migration              False
# 7810      118A         The History of American Advertising              False
# 7811       10B               The Biology of Women's Health              False
# 7812       98A                           Independent Study               True
#
#       term                                        description
# 0     1203  Meets for one-half semester and yields half-co...
# 1     1203  Meets for one-half semester and yields half-co...
# 2     1203  Meets for one-half semester and yields half-co...
# 3     1203  Meets for one-half semester and yields half-co...
# 4     1203  Meets for one-half semester and yields half-co...
# ...    ...                                                ...
# 7808  1212  Enrollment varies according to instructor. Ref...
# 7809  1212  Investigates the social, cultural, religious, ...
# 7810  1212  Considers American advertising from the eighte...
# 7811  1212  Does not meet the requirements for the major i...
# 7812  1212                 Usually offered every year.\nStaff
#
# [7813 rows x 17 columns]

# %%
pt =  df.groupby('subject')['enrolled'].agg([np.sum])
pt.sort_values('sum',ascending=False).head(10)
# Out:
#           sum
# subject
# HS       5318
# BIOL     3085
# BUS      2766
# HWL      2734
# CHEM     2322
# ECON     2315
# COSI     2223
# MATH     1785
# PSYC     1704
# ANTH     1144

# %%
df['email']=df['instructor'].apply(lambda x: x[2])

# %%
pt2 =  df[df['subject']=='COSI'].groupby('email')['enrolled'].agg([np.sum])
pt2.sort_values('sum',ascending=False).head(20)
# Out:
#                           sum
# email
# tjhickey@brandeis.edu     411
# dilant@brandeis.edu       342
# tsekourakis@brandeis.edu  316
# rpsalas@brandeis.edu      128
# pollack@brandeis.edu      126
# hongpeng@brandeis.edu     114
# lignos@brandeis.edu       106
# storer@brandeis.edu       104
# mfc@brandeis.edu          101
# mairson@brandeis.edu       85
# ralterma@brandeis.edu      63
# jamesp@brandeis.edu        61
# xuen@brandeis.edu          52
# hongfuliu@brandeis.edu     42
# opapaemm@brandeis.edu      41
# panick@brandeis.edu        32
# golitsyn@brandeis.edu      29
# chuxuzhang@brandeis.edu    26
# wellner@brandeis.edu       15
# mmeteer@brandeis.edu       10
